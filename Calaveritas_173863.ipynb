# %% [markdown]
# #Creation of Calaveritas
# ##Rodrigo Espíritu Berra 173863

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Cargar el archivo de calaveritas
with open("calaveritas.csv", "r", encoding="utf-8") as file:
    calaveritas_text = file.read()

# %%
# Dividir las calaveritas en una lista de poemas, cada uno separado por un salto de línea doble (\n\n)
calaveritas = calaveritas_text.strip().split("\n\n")

# Crear el DataFrame
calaveritas_df = pd.DataFrame({"calaverita": calaveritas})

# Ver el DataFrame
calaveritas_df.head()
# Out:
#                                           calaverita
# 0  calaverita\n"El estudiante tan valiente,\nen l...

# %%
# Cargar y Preprocesar los Datos
calaveritas_text = " ".join(calaveritas_df["calaverita"])

# Tokenización del texto
tokenizer = Tokenizer(char_level=True)  # Tokenización a nivel de carácter
tokenizer.fit_on_texts([calaveritas_text])
total_chars = len(tokenizer.word_index) + 1

# Convertir el texto en secuencias de enteros
input_sequences = []
for i in range(1, len(calaveritas_text)):
    sequence = calaveritas_text[:i + 1]
    token_list = tokenizer.texts_to_sequences([sequence])[0]
    input_sequences.append(token_list)

# Asegurar que todas las secuencias tengan la misma longitud
max_sequence_len = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')

# Dividir en entradas (X) y etiquetas (y)
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_chars)

# Construir el Modelo RNN
model = Sequential([
    Embedding(total_chars, 64, input_length=max_sequence_len - 1),
    LSTM(100, return_sequences=True),
    LSTM(100),
    Dense(total_chars, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Entrenar el Modelo
history = model.fit(X, y, epochs=100, verbose=1)

# Generar nuevas Calaveritas
def generate_calaverita(seed_text, next_chars=100):
    for _ in range(next_chars):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)
        output_char = tokenizer.index_word[predicted[0]]
        seed_text += output_char
    return seed_text

# Ejemplo de generación de calaverita
seed_text = "La muerte llegó"
print(generate_calaverita(seed_text, next_chars=100))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 87ms/step - accuracy: 0.0783 - loss: 3.4544
# Epoch 2/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.1289 - loss: 3.0616
# Epoch 3/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.1404 - loss: 3.0812
# Epoch 4/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.1339 - loss: 3.0312
# Epoch 5/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.1324 - loss: 3.0423
# Epoch 6/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.1399 - loss: 3.0398
# Epoch 7/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.2228 - loss: 2.9421
# Epoch 8/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.2259 - loss: 2.8668
# Epoch 9/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.2249 - loss: 2.7091
# Epoch 10/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.2970 - loss: 2.5889
# Epoch 11/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.3130 - loss: 2.4792
# Epoch 12/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.3347 - loss: 2.3693
# Epoch 13/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3552 - loss: 2.2979
# Epoch 14/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.3624 - loss: 2.1455
# Epoch 15/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.3810 - loss: 2.0863
# Epoch 16/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.3925 - loss: 2.0436
# Epoch 17/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.3676 - loss: 2.0413
# Epoch 18/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.4100 - loss: 1.9876
# Epoch 19/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.4439 - loss: 1.9047
# Epoch 20/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.4640 - loss: 1.8606
# Epoch 21/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.4561 - loss: 1.8630
# Epoch 22/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.4826 - loss: 1.7751
# Epoch 23/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.4965 - loss: 1.7638
# Epoch 24/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.4956 - loss: 1.7478
# Epoch 25/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.5228 - loss: 1.6520
# Epoch 26/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.5270 - loss: 1.5864
# Epoch 27/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.5558 - loss: 1.5625
# Epoch 28/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.5408 - loss: 1.5255
# Epoch 29/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.5405 - loss: 1.5565
# Epoch 30/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.5376 - loss: 1.5466
# Epoch 31/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.5661 - loss: 1.4833
# Epoch 32/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.6019 - loss: 1.4012
# Epoch 33/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.6091 - loss: 1.3526
# Epoch 34/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.6049 - loss: 1.3254
# Epoch 35/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.6074 - loss: 1.2891
# Epoch 36/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.6454 - loss: 1.2925
# Epoch 37/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.6486 - loss: 1.2027
# Epoch 38/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.6471 - loss: 1.2155
# Epoch 39/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.6769 - loss: 1.1342
# Epoch 40/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.6582 - loss: 1.1292
# Epoch 41/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.6755 - loss: 1.0813
# Epoch 42/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.7167 - loss: 0.9895
# Epoch 43/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.7129 - loss: 1.0062
# Epoch 44/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.7128 - loss: 0.9802
# Epoch 45/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.7377 - loss: 0.9260
# Epoch 46/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.7388 - loss: 0.9403
# Epoch 47/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.7858 - loss: 0.8418
# Epoch 48/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.7458 - loss: 0.9212
# Epoch 49/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.7711 - loss: 0.8591
# Epoch 50/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.8281 - loss: 0.7393
# Epoch 51/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.8070 - loss: 0.7742
# Epoch 52/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.8287 - loss: 0.7076
# Epoch 53/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.8346 - loss: 0.6978
# Epoch 54/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.8536 - loss: 0.6449
# Epoch 55/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.8544 - loss: 0.6179
# Epoch 56/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.8656 - loss: 0.6104
# Epoch 57/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.8387 - loss: 0.6609
# Epoch 58/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.8695 - loss: 0.5901
# Epoch 59/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.8802 - loss: 0.5250
# Epoch 60/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.9074 - loss: 0.4910
# Epoch 61/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.9020 - loss: 0.5048
# Epoch 62/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9057 - loss: 0.4726
# Epoch 63/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.8930 - loss: 0.4498
# Epoch 64/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.9072 - loss: 0.4482
# Epoch 65/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9245 - loss: 0.4027
# Epoch 66/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.9160 - loss: 0.4391
# Epoch 67/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.9317 - loss: 0.3869
# Epoch 68/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.8976 - loss: 0.4668
# Epoch 69/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.9472 - loss: 0.3582
# Epoch 70/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.9501 - loss: 0.3565
# Epoch 71/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - accuracy: 0.9463 - loss: 0.3216
# Epoch 72/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9518 - loss: 0.3119
# Epoch 73/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.9594 - loss: 0.3032
# Epoch 74/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9716 - loss: 0.2760
# Epoch 75/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.9740 - loss: 0.2452
# Epoch 76/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9856 - loss: 0.2341
# Epoch 77/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9780 - loss: 0.2347
# Epoch 78/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.9350 - loss: 0.3232
# Epoch 79/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9501 - loss: 0.3262
# Epoch 80/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.9532 - loss: 0.2738
# Epoch 81/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.9746 - loss: 0.2244
# Epoch 82/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9832 - loss: 0.1966
# Epoch 83/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.9892 - loss: 0.1824
# Epoch 84/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9939 - loss: 0.1678
# Epoch 85/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.9923 - loss: 0.1509
# Epoch 86/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.9971 - loss: 0.1444
# Epoch 87/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9813 - loss: 0.1944
# Epoch 88/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.9936 - loss: 0.1515
# Epoch 89/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.9940 - loss: 0.1317
# Epoch 90/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9936 - loss: 0.1261
# Epoch 91/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9869 - loss: 0.1467
# Epoch 92/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9917 - loss: 0.1219
# Epoch 93/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9962 - loss: 0.1171
# Epoch 94/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.9934 - loss: 0.1091
# Epoch 95/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9949 - loss: 0.1037
# Epoch 96/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9975 - loss: 0.0912
# Epoch 97/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.9960 - loss: 0.0896
# Epoch 98/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.9965 - loss: 0.0788
# Epoch 99/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9966 - loss: 0.0868
# Epoch 100/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - accuracy: 0.9976 - loss: 0.0761
# La muerte llegó entente,
# y se la llevó amablemente."
# "el bombero muy valiente,
# apagando fuego de frente.
# la muerte
